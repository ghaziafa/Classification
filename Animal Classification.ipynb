# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_table(r'C:\Users\User\Desktop\animal data set\dataset\anage_data.txt')

# %%
df.head()
# Out:
#    HAGRID   Kingdom      Phylum         Class        Order         Family  \
# 0       3  Animalia  Arthropoda  Branchiopoda  Diplostraca     Daphniidae
# 1       5  Animalia  Arthropoda       Insecta      Diptera  Drosophilidae
# 2       6  Animalia  Arthropoda       Insecta  Hymenoptera         Apidae
# 3       8  Animalia  Arthropoda       Insecta  Hymenoptera     Formicidae
# 4       9  Animalia  Arthropoda       Insecta  Hymenoptera     Formicidae
#
#            Genus       Species              Common name  \
# 0        Daphnia     pulicaria                  Daphnia
# 1     Drosophila  melanogaster                Fruit fly
# 2           Apis     mellifera                Honey bee
# 3  Cardiocondyla     obscurior  Cardiocondyla obscurior
# 4         Lasius         niger         Black garden ant
#
#    Female maturity (days)  ...  Source  Specimen origin  Sample size  \
# 0                     NaN  ...     NaN          unknown       medium
# 1                     7.0  ...     NaN        captivity        large
# 2                     NaN  ...     812          unknown       medium
# 3                     NaN  ...    1293        captivity       medium
# 4                     NaN  ...     411          unknown       medium
#
#    Data quality  IMR (per yr)  MRDT (yrs)  Metabolic rate (W)  Body mass (g)  \
# 0    acceptable           NaN         NaN                 NaN            NaN
# 1    acceptable          0.05        0.04                 NaN            NaN
# 2    acceptable           NaN         NaN                 NaN            NaN
# 3    acceptable           NaN         NaN                 NaN            NaN
# 4    acceptable           NaN         NaN                 NaN            NaN
#
#    Temperature (K)                                         References
# 0              NaN                                     1294,1295,1296
# 1              NaN  2,20,32,47,53,68,69,240,241,242,243,274,602,98...
# 2              NaN  63,407,408,741,805,806,808,812,815,828,830,831...
# 3              NaN                                               1293
# 4              NaN                                        411,813,814
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (4219, 31)

# %%
d1={'HAGRID':'Hagrid', 'Common name':'Common_name', 'Female maturity (days)':'Female_maturity_days',
       'Male maturity (days)':'Male_maturity_days', 'Gestation/Incubation (days)':'Gestation_Incubation_days',
       'Weaning (days)':'Weaning_days',
       'Litter/Clutch size':'Litter_Clutch_size', 'Litters/Clutches per year':'Litters_Clutches_per_year',
       'Inter-litter/Interbirth interval':'Inter_litter_Interbirth_interval', 'Birth weight (g)':'Birth_weight_g',
       'Weaning weight (g)':'Weaning_weight_g', 'Adult weight (g)':'Adult_weight_g', 'Growth rate (1/days)':'Growth_rate_1_days_',
       'Maximum longevity (yrs)':'Maximum_longevity_yrs', 'Specimen origin':'Specimen_origin', 'Sample size':'Sample_size',
       'Data quality':'Data_quality', 'IMR (per yr)':'IMR_per_yr', 'MRDT (yrs)':'MRDT_yrs', 'Metabolic rate (W)':'Metabolic_rate_W',
       'Body mass (g)':'Body_mass_g', 'Temperature (K)':'Temperature_K'}

# %%
df.rename(columns = d1, inplace = True)

# %%
mam = df.loc[df.Class== 'Mammalia']

# %%
mam.drop(columns = ['Hagrid','Kingdom','Phylum'], inplace = True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
mam.Order.value_counts().head(28)
# Out:
# Rodentia            358
# Carnivora           205
# Primates            174
# Artiodactyla        172
# Chiroptera           96
# Diprotodontia        72
# Cetacea              45
# Dasyuromorphia       38
# Soricomorpha         33
# Lagomorpha           20
# Didelphimorphia      20
# Perissodactyla       16
# Cingulata            13
# Erinaceomorpha       10
# Peramelemorphia      10
# Macroscelidea         9
# Pilosa                8
# Afrosoricida          7
# Scandentia            6
# Hyracoidea            3
# Monotremata           3
# Sirenia               3
# Pholidota             2
# Proboscidea           2
# Microbiotheria        1
# Notoryctemorphia      1
# Dermoptera            1
# Tubulidentata         1
# Name: Order, dtype: int64

# %%
plt.figure(figsize = (20,8))
plt.barh(mam.Order.value_counts().index,mam.Order.value_counts())
# Out:
# <BarContainer object of 28 artists>

# %%
apes=mam.loc[mam.Family=='Hominidae']

# %%
apes
# Out:
#          Class     Order     Family    Genus      Species  \
# 2406  Mammalia  Primates  Hominidae  Gorilla      gorilla
# 2407  Mammalia  Primates  Hominidae     Homo      sapiens
# 2408  Mammalia  Primates  Hominidae      Pan     paniscus
# 2409  Mammalia  Primates  Hominidae      Pan  troglodytes
# 2410  Mammalia  Primates  Hominidae    Pongo     pygmaeus
#
#                      Common_name  Female_maturity_days  Male_maturity_days  \
# 2406                     Gorilla                2829.0              4015.0
# 2407                       Human                4745.0              5110.0
# 2408  Pygmy chimpanzee or bonobo                3194.0                 NaN
# 2409                  Chimpanzee                3376.0              2920.0
# 2410                   Orangutan                2555.0              2555.0
#
#       Gestation_Incubation_days  Weaning_days  ...  Source  Specimen_origin  \
# 2406                      256.0         834.0  ...    1151        captivity
# 2407                      280.0         639.0  ...      29        captivity
# 2408                      232.0         635.0  ...     671        captivity
# 2409                      229.0        1111.0  ...     671        captivity
# 2410                      249.0        1003.0  ...     671        captivity
#
#       Sample_size  Data_quality  IMR_per_yr  MRDT_yrs  Metabolic_rate_W  \
# 2406        large    acceptable         NaN       NaN               NaN
# 2407         huge          high      0.0002       8.0             82.78
# 2408         tiny    acceptable         NaN       NaN               NaN
# 2409        large    acceptable      0.0400       8.0               NaN
# 2410        large    acceptable         NaN       NaN               NaN
#
#       Body_mass_g Temperature_K  \
# 2406          NaN        308.65
# 2407      70000.0        310.15
# 2408          NaN           NaN
# 2409          NaN        308.85
# 2410          NaN           NaN
#
#                                              References
# 2406  59,341,342,434,436,455,467,610,671,679,680,681...
# 2407  2,13,14,29,30,31,36,58,59,65,75,76,110,111,121...
# 2408  108,256,323,324,434,436,455,463,467,569,590,67...
# 2409  8,59,72,73,234,235,236,237,238,239,256,323,434...
# 2410  59,75,108,164,214,215,434,436,455,467,610,671,...
#
# [5 rows x 28 columns]

# %%
CN = apes.Common_name

# %%
CN
# Out:
# 2406                       Gorilla
# 2407                         Human
# 2408    Pygmy chimpanzee or bonobo
# 2409                    Chimpanzee
# 2410                     Orangutan
# Name: Common_name, dtype: object

# %%
plt.figure(figsize=(20,10))
plt.subplot(221)
plt.bar(CN,apes.Adult_weight_g)
plt.title('Adult Weight')
plt.subplot(222)
plt.bar(CN,apes.Female_maturity_days)
plt.title('Female maturity days')
plt.subplot(223)
plt.bar(CN,apes.Maximum_longevity_yrs)
plt.title('Maximum Longetivity')
plt.subplot(224)
plt.bar(CN,apes.Birth_weight_g)
plt.title('Birth Weight')
# Out:
# Text(0.5, 1.0, 'Birth Weight')

# %%
mam.describe()
# Out:
#        Female_maturity_days  Male_maturity_days  Gestation_Incubation_days  \
# count            860.000000          574.000000                1024.000000
# mean             685.967442          806.604530                 121.554688
# std              772.129778          922.912382                 107.963242
# min               24.000000           36.000000                  10.000000
# 25%              243.000000          291.750000                  31.000000
# 50%              391.500000          460.000000                  76.500000
# 75%              803.750000          914.000000                 180.000000
# max             8212.000000         8212.000000                 670.000000
#
#        Weaning_days  Litter_Clutch_size  Litters_Clutches_per_year  \
# count    810.000000         1232.000000                 813.000000
# mean     143.759259            2.539866                   1.569459
# std      165.824986            2.050873                   1.204807
# min        7.000000            1.000000                   0.100000
# 25%       36.000000            1.000000                   1.000000
# 50%       77.000000            2.000000                   1.000000
# 75%      182.750000            3.525000                   2.000000
# max     1111.000000           22.200000                  10.000000
#
#        Inter_litter_Interbirth_interval  Birth_weight_g  Weaning_weight_g  \
# count                        656.000000    8.490000e+02      4.050000e+02
# mean                         355.807927    1.656514e+04      5.470319e+04
# std                          274.439414    1.287223e+05      8.462728e+05
# min                           20.000000    4.000000e-03      2.065000e+00
# 25%                          181.250000    4.460000e+00      2.170000e+01
# 50%                          365.000000    5.550000e+01      2.140000e+02
# 75%                          365.000000    7.000000e+02      2.170000e+03
# max                         1825.000000    2.000000e+06      1.700000e+07
#
#        Adult_weight_g  Growth_rate_1_days_  Maximum_longevity_yrs  IMR_per_yr  \
# count    1.310000e+03           250.000000            1012.000000   15.000000
# mean     4.618394e+05             0.027931              19.826581    0.040493
# std      5.473929e+06             0.032425              15.551026    0.090328
# min      2.100000e+00             0.000300               2.100000    0.000200
# 25%      1.050000e+02             0.007925               9.375000    0.002000
# 50%      1.399300e+03             0.017750              17.150000    0.015000
# 75%      1.157500e+04             0.035850              25.425000    0.030000
# max      1.360000e+08             0.216000             211.000000    0.360000
#
#         MRDT_yrs  Metabolic_rate_W   Body_mass_g  Temperature_K
# count  17.000000        422.000000  4.220000e+02     457.000000
# mean    6.447059         16.752974  1.904198e+04     309.730306
# std     5.695845        118.526036  1.834545e+05       1.756006
# min     0.300000          0.027000  2.400000e+00     303.850000
# 25%     2.000000          0.333500  4.477500e+01     308.700000
# 50%     4.000000          0.881500  2.400000e+02     309.850000
# 75%     8.000000          4.502500  2.360075e+03     311.150000
# max    20.000000       2336.500000  3.672000e+06     313.850000

# %%
num_col=mam.describe().columns #to extract numerical vlanes from table

# %%
mam.isnull()
# Out:
#       Class  Order  Family  Genus  Species  Common_name  Female_maturity_days  \
# 1530  False  False   False  False    False        False                 False
# 1531  False  False   False  False    False        False                  True
# 1532  False  False   False  False    False        False                 False
# 1533  False  False   False  False    False        False                 False
# 1534  False  False   False  False    False        False                 False
# ...     ...    ...     ...    ...      ...          ...                   ...
# 2854  False  False   False  False    False        False                  True
# 2855  False  False   False  False    False        False                 False
# 2856  False  False   False  False    False        False                 False
# 2857  False  False   False  False    False        False                 False
# 2858  False  False   False  False    False        False                 False
#
#       Male_maturity_days  Gestation_Incubation_days  Weaning_days  ...  \
# 1530               False                      False         False  ...
# 1531                True                      False         False  ...
# 1532                True                      False         False  ...
# 1533               False                      False         False  ...
# 1534               False                      False         False  ...
# ...                  ...                        ...           ...  ...
# 2854                True                      False          True  ...
# 2855               False                      False         False  ...
# 2856               False                      False         False  ...
# 2857               False                      False         False  ...
# 2858               False                      False         False  ...
#
#       Source  Specimen_origin  Sample_size  Data_quality  IMR_per_yr  \
# 1530   False            False        False         False        True
# 1531    True            False        False         False        True
# 1532   False            False        False         False        True
# 1533   False            False        False         False        True
# 1534   False            False        False         False        True
# ...      ...              ...          ...           ...         ...
# 2854   False            False        False         False        True
# 2855    True            False        False         False        True
# 2856    True            False        False         False        True
# 2857    True            False        False         False        True
# 2858   False            False        False         False        True
#
#       MRDT_yrs  Metabolic_rate_W  Body_mass_g  Temperature_K  References
# 1530      True             False        False          False       False
# 1531      True             False        False          False       False
# 1532      True             False        False          False       False
# 1533      True             False        False          False       False
# 1534      True             False        False          False       False
# ...        ...               ...          ...            ...         ...
# 2854      True              True         True           True       False
# 2855      True              True         True           True       False
# 2856      True             False        False          False       False
# 2857      True              True         True           True       False
# 2858      True             False        False          False       False
#
# [1329 rows x 28 columns]

# %%
mam.isnull().sum()
# Out:
# Class                                  0
# Order                                  0
# Family                                 0
# Genus                                  0
# Species                                0
# Common_name                            0
# Female_maturity_days                 469
# Male_maturity_days                   755
# Gestation_Incubation_days            305
# Weaning_days                         519
# Litter_Clutch_size                    97
# Litters_Clutches_per_year            516
# Inter_litter_Interbirth_interval     673
# Birth_weight_g                       480
# Weaning_weight_g                     924
# Adult_weight_g                        19
# Growth_rate_1_days_                 1079
# Maximum_longevity_yrs                317
# Source                               319
# Specimen_origin                        0
# Sample_size                            0
# Data_quality                           0
# IMR_per_yr                          1314
# MRDT_yrs                            1312
# Metabolic_rate_W                     907
# Body_mass_g                          907
# Temperature_K                        872
# References                             0
# dtype: int64

# %%
plt.figure(figsize = (20,10))
plt.barh(mam.isnull().sum().index,mam.isnull().sum()/len(mam)*100)
plt.title('percentage missind data')
# Out:
# Text(0.5, 1.0, 'percentage missind data')

# %%
mam.drop(columns=['Class','Family','Genus','Species','Common_name','References'],inplace=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
mam.head()
# Out:
#              Order  Female_maturity_days  Male_maturity_days  \
# 1530  Afrosoricida                 365.0               365.0
# 1531  Afrosoricida                   NaN                 NaN
# 1532  Afrosoricida                  35.0                 NaN
# 1533  Afrosoricida                 669.0               669.0
# 1534  Afrosoricida                 639.0               639.0
#
#       Gestation_Incubation_days  Weaning_days  Litter_Clutch_size  \
# 1530                       55.0          29.0                6.00
# 1531                       63.0          37.0                3.90
# 1532                       59.0          21.0                4.00
# 1533                       61.0          29.0                2.67
# 1534                       61.0          29.0                2.00
#
#       Litters_Clutches_per_year  Inter_litter_Interbirth_interval  \
# 1530                        1.0                               NaN
# 1531                        2.0                               NaN
# 1532                        2.0                               NaN
# 1533                        NaN                               NaN
# 1534                        NaN                               NaN
#
#       Birth_weight_g  Weaning_weight_g  ...  Maximum_longevity_yrs  Source  \
# 1530            7.67              50.0  ...                   19.0     671
# 1531            0.70               NaN  ...                    NaN     NaN
# 1532           11.50               NaN  ...                    2.7     671
# 1533            3.95               NaN  ...                    5.6     434
# 1534            3.60               NaN  ...                    5.8     434
#
#       Specimen_origin Sample_size  Data_quality IMR_per_yr MRDT_yrs  \
# 1530        captivity      medium    acceptable        NaN      NaN
# 1531          unknown       small           low        NaN      NaN
# 1532        captivity       small  questionable        NaN      NaN
# 1533        captivity       small    acceptable        NaN      NaN
# 1534        captivity       small    acceptable        NaN      NaN
#
#       Metabolic_rate_W  Body_mass_g  Temperature_K
# 1530             0.750        116.4         307.85
# 1531             0.043          6.9         303.95
# 1532             0.380        116.4         308.15
# 1533             0.315         44.6         304.05
# 1534             0.243         44.0         303.95
#
# [5 rows x 22 columns]

# %%
mam.drop(columns=['Specimen_origin','Sample_size','Data_quality','Source'],inplace=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
mam.dtypes
# Out:
# Order                                object
# Female_maturity_days                float64
# Male_maturity_days                  float64
# Gestation_Incubation_days           float64
# Weaning_days                        float64
# Litter_Clutch_size                  float64
# Litters_Clutches_per_year           float64
# Inter_litter_Interbirth_interval    float64
# Birth_weight_g                      float64
# Weaning_weight_g                    float64
# Adult_weight_g                      float64
# Growth_rate_1_days_                 float64
# Maximum_longevity_yrs               float64
# IMR_per_yr                          float64
# MRDT_yrs                            float64
# Metabolic_rate_W                    float64
# Body_mass_g                         float64
# Temperature_K                       float64
# dtype: object

# %%
mam.isnull().sum()/len(mam)*100
# Out:
# Order                                0.000000
# Female_maturity_days                35.289691
# Male_maturity_days                  56.809631
# Gestation_Incubation_days           22.949586
# Weaning_days                        39.051919
# Litter_Clutch_size                   7.298721
# Litters_Clutches_per_year           38.826185
# Inter_litter_Interbirth_interval    50.639579
# Birth_weight_g                      36.117381
# Weaning_weight_g                    69.525959
# Adult_weight_g                       1.429646
# Growth_rate_1_days_                 81.188864
# Maximum_longevity_yrs               23.852521
# IMR_per_yr                          98.871332
# MRDT_yrs                            98.720843
# Metabolic_rate_W                    68.246802
# Body_mass_g                         68.246802
# Temperature_K                       65.613243
# dtype: float64

# %%
mam.drop(columns=['IMR_per_yr','MRDT_yrs','Growth_rate_1_days_'],inplace=True)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(mam.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
mam.drop(columns= ['Male_maturity_days','Body_mass_g','Weaning_weight_g','Metabolic_rate_W','Inter_litter_Interbirth_interval'], inplace = True)

# %%
mam.isnull()
# Out:
#       Order  Female_maturity_days  Gestation_Incubation_days  Weaning_days  \
# 1530  False                 False                      False         False
# 1531  False                  True                      False         False
# 1532  False                 False                      False         False
# 1533  False                 False                      False         False
# 1534  False                 False                      False         False
# ...     ...                   ...                        ...           ...
# 2854  False                  True                      False          True
# 2855  False                 False                      False         False
# 2856  False                 False                      False         False
# 2857  False                 False                      False         False
# 2858  False                 False                      False         False
#
#       Litter_Clutch_size  Litters_Clutches_per_year  Birth_weight_g  \
# 1530               False                      False           False
# 1531               False                      False           False
# 1532               False                      False           False
# 1533               False                       True           False
# 1534               False                       True           False
# ...                  ...                        ...             ...
# 2854               False                      False            True
# 2855               False                      False           False
# 2856               False                      False           False
# 2857               False                      False           False
# 2858               False                      False           False
#
#       Adult_weight_g  Maximum_longevity_yrs  Temperature_K
# 1530           False                  False          False
# 1531           False                   True          False
# 1532           False                  False          False
# 1533           False                  False          False
# 1534           False                  False          False
# ...              ...                    ...            ...
# 2854           False                  False           True
# 2855           False                   True           True
# 2856           False                   True          False
# 2857           False                   True           True
# 2858           False                  False          False
#
# [1329 rows x 10 columns]

# %%
mam.isnull().sum()
# Out:
# Order                          0
# Female_maturity_days         469
# Gestation_Incubation_days    305
# Weaning_days                 519
# Litter_Clutch_size            97
# Litters_Clutches_per_year    516
# Birth_weight_g               480
# Adult_weight_g                19
# Maximum_longevity_yrs        317
# Temperature_K                872
# dtype: int64

# %%
mam.Temperature_K.fillna(mam.Temperature_K.median(),inplace= True)

# %%
mam.shape
# Out:
# (1329, 10)

# %%
 X = mam.dropna()

# %%
X.shape
# Out:
# (438, 10)

# %%
Y = X.Order

# %%
Y
# Out:
# 1530     Afrosoricida
# 1532     Afrosoricida
# 1535     Afrosoricida
# 1536     Afrosoricida
# 1537     Artiodactyla
#             ...
# 2838     Soricomorpha
# 2850     Soricomorpha
# 2851     Soricomorpha
# 2852     Soricomorpha
# 2858    Tubulidentata
# Name: Order, Length: 438, dtype: object

# %%
X.drop(columns = 'Order', inplace = True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
from sklearn.model_selection import train_test_split

# %%
#importing Classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((328, 9), (110, 9), (328,), (110,))

# %%
model_DT=DecisionTreeClassifier()
model_RF=RandomForestClassifier()
model_GB=GradientBoostingClassifier()

# %%
model = [model_DT,model_RF,model_GB]

# %%
from sklearn.metrics import accuracy_score

# %%
def accuracy_calculator(x_train,x_test,y_train,y_test,model):
    for i in range(len(model)):
        model[i].fit(x_train,y_train)
        print('model'+str(i)+' training accuracy: '+str(accuracy_score(model[i].predict(x_train),y_train)))
        print('model'+str(i)+' test accuracy: '+str(accuracy_score(model[i].predict(x_test),y_test)))

# %%
accuracy_calculator(x_train,x_test,y_train,y_test,model)
# Out:
# model0 training accuracy: 1.0
# model0 test accuracy: 0.6818181818181818
# model1 training accuracy: 1.0
# model1 test accuracy: 0.7727272727272727
# model2 training accuracy: 1.0
# model2 test accuracy: 0.7545454545454545

# %%
model_RF.feature_importances_
# Out:
# array([0.10294215, 0.16960909, 0.10978996, 0.09367456, 0.04019634,
#        0.18883619, 0.12993959, 0.10736998, 0.05764214])

# %%
x_train.columns
# Out:
# Index(['Female_maturity_days', 'Gestation_Incubation_days', 'Weaning_days',
#        'Litter_Clutch_size', 'Litters_Clutches_per_year', 'Birth_weight_g',
#        'Adult_weight_g', 'Maximum_longevity_yrs', 'Temperature_K'],
#       dtype='object')

# %%
T1=zip(x_train.columns,model_RF.feature_importances_*100)

# %%
T1

# %%
list(T1)
# Out:
# [('Female_maturity_days', 10.294214707928347),
#  ('Gestation_Incubation_days', 16.96090921900483),
#  ('Weaning_days', 10.978995872472964),
#  ('Litter_Clutch_size', 9.367455603108137),
#  ('Litters_Clutches_per_year', 4.019634238657975),
#  ('Birth_weight_g', 18.883618591619417),
#  ('Adult_weight_g', 12.993959388455256),
#  ('Maximum_longevity_yrs', 10.736998031366465),
#  ('Temperature_K', 5.76421434738662)]

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()

# %%
x_train_st=st.fit_transform(x_train)

# %%
x_test_st=st.fit_transform(x_test)

# %%
model_MLP=MLPClassifier()

# %%
model_MLP.fit(x_train_st,y_train)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
accuracy_score(model_MLP.predict(x_train_st),y_train)
# Out:
# 0.7713414634146342

# %%
accuracy_score(model_MLP.predict(x_test_st),y_test)
# Out:
# 0.6545454545454545

# %%
mam.head()
# Out:
#              Order  Female_maturity_days  Gestation_Incubation_days  \
# 1530  Afrosoricida                 365.0                       55.0
# 1531  Afrosoricida                   NaN                       63.0
# 1532  Afrosoricida                  35.0                       59.0
# 1533  Afrosoricida                 669.0                       61.0
# 1534  Afrosoricida                 639.0                       61.0
#
#       Weaning_days  Litter_Clutch_size  Litters_Clutches_per_year  \
# 1530          29.0                6.00                        1.0
# 1531          37.0                3.90                        2.0
# 1532          21.0                4.00                        2.0
# 1533          29.0                2.67                        NaN
# 1534          29.0                2.00                        NaN
#
#       Birth_weight_g  Adult_weight_g  Maximum_longevity_yrs  Temperature_K
# 1530            7.67           180.0                   19.0         307.85
# 1531            0.70             6.7                    NaN         303.95
# 1532           11.50           180.0                    2.7         308.15
# 1533            3.95            37.8                    5.6         304.05
# 1534            3.60            50.0                    5.8         303.95

# %%
mam.isnull()
# Out:
#       Order  Female_maturity_days  Gestation_Incubation_days  Weaning_days  \
# 1530  False                 False                      False         False
# 1531  False                  True                      False         False
# 1532  False                 False                      False         False
# 1533  False                 False                      False         False
# 1534  False                 False                      False         False
# ...     ...                   ...                        ...           ...
# 2854  False                  True                      False          True
# 2855  False                 False                      False         False
# 2856  False                 False                      False         False
# 2857  False                 False                      False         False
# 2858  False                 False                      False         False
#
#       Litter_Clutch_size  Litters_Clutches_per_year  Birth_weight_g  \
# 1530               False                      False           False
# 1531               False                      False           False
# 1532               False                      False           False
# 1533               False                       True           False
# 1534               False                       True           False
# ...                  ...                        ...             ...
# 2854               False                      False            True
# 2855               False                      False           False
# 2856               False                      False           False
# 2857               False                      False           False
# 2858               False                      False           False
#
#       Adult_weight_g  Maximum_longevity_yrs  Temperature_K
# 1530           False                  False          False
# 1531           False                   True          False
# 1532           False                  False          False
# 1533           False                  False          False
# 1534           False                  False          False
# ...              ...                    ...            ...
# 2854           False                  False          False
# 2855           False                   True          False
# 2856           False                   True          False
# 2857           False                   True          False
# 2858           False                  False          False
#
# [1329 rows x 10 columns]

# %%
X= mam.dropna()

# %%
X
# Out:
#               Order  Female_maturity_days  Gestation_Incubation_days  \
# 1530   Afrosoricida                 365.0                       55.0
# 1532   Afrosoricida                  35.0                       59.0
# 1535   Afrosoricida                 198.0                       54.0
# 1536   Afrosoricida                 182.0                       58.0
# 1537   Artiodactyla                 547.0                      235.0
# ...             ...                   ...                        ...
# 2838   Soricomorpha                 198.0                       21.0
# 2850   Soricomorpha                 365.0                       27.0
# 2851   Soricomorpha                  36.0                       30.0
# 2852   Soricomorpha                 304.0                       40.0
# 2858  Tubulidentata                 730.0                      225.0
#
#       Weaning_days  Litter_Clutch_size  Litters_Clutches_per_year  \
# 1530          29.0                 6.0                        1.0
# 1532          21.0                 4.0                        2.0
# 1535          24.0                 3.0                        1.0
# 1536          27.0                18.0                        1.5
# 1537          91.0                 2.0                        1.0
# ...            ...                 ...                        ...
# 2838          25.0                 6.0                        1.9
# 2850          20.0                 4.0                        3.4
# 2851          19.0                 3.0                        9.8
# 2852          24.0                 4.4                        1.0
# 2858         103.0                 1.0                        1.0
#
#       Birth_weight_g  Adult_weight_g  Maximum_longevity_yrs  Temperature_K
# 1530            7.67           180.0                   19.0         307.85
# 1532           11.50           180.0                    2.7         308.15
# 1535           24.70           225.0                   14.1         305.35
# 1536           21.00           900.0                    8.7         306.15
# 1537         3000.00         46100.0                   15.5         311.15
# ...              ...             ...                    ...            ...
# 2838            0.44             9.0                    3.2         308.15
# 2850            0.19             2.1                    3.2         309.15
# 2851            2.68            45.9                    3.2         311.85
# 2852            1.50            55.3                    2.5         310.85
# 2858         1800.00         60000.0                   29.8         307.65
#
# [438 rows x 10 columns]

# %%
X.isnull()
# Out:
#       Order  Female_maturity_days  Gestation_Incubation_days  Weaning_days  \
# 1530  False                 False                      False         False
# 1532  False                 False                      False         False
# 1535  False                 False                      False         False
# 1536  False                 False                      False         False
# 1537  False                 False                      False         False
# ...     ...                   ...                        ...           ...
# 2838  False                 False                      False         False
# 2850  False                 False                      False         False
# 2851  False                 False                      False         False
# 2852  False                 False                      False         False
# 2858  False                 False                      False         False
#
#       Litter_Clutch_size  Litters_Clutches_per_year  Birth_weight_g  \
# 1530               False                      False           False
# 1532               False                      False           False
# 1535               False                      False           False
# 1536               False                      False           False
# 1537               False                      False           False
# ...                  ...                        ...             ...
# 2838               False                      False           False
# 2850               False                      False           False
# 2851               False                      False           False
# 2852               False                      False           False
# 2858               False                      False           False
#
#       Adult_weight_g  Maximum_longevity_yrs  Temperature_K
# 1530           False                  False          False
# 1532           False                  False          False
# 1535           False                  False          False
# 1536           False                  False          False
# 1537           False                  False          False
# ...              ...                    ...            ...
# 2838           False                  False          False
# 2850           False                  False          False
# 2851           False                  False          False
# 2852           False                  False          False
# 2858           False                  False          False
#
# [438 rows x 10 columns]
